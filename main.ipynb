# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
taxi_df = pd.read_parquet("data/yellow_tripdata_2019-01.parquet")

# %%
taxi_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# 1            2.6         1.0                  N           239           246
# 2            0.0         1.0                  N           236           236
# 3            0.0         1.0                  N           193           193
# 4            0.0         2.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
taxi_df.shape
# Out:
# (7696617, 19)

# %%
taxi_df['passenger_count'].value_counts()
# Out:
# passenger_count
# 1.0    5456515
# 2.0    1113894
# 5.0     323842
# 3.0     314692
# 6.0     200811
# 4.0     140753
# 0.0     117381
# 8.0         29
# 7.0         19
# 9.0          9
# Name: count, dtype: int64

# %%
taxi_df[taxi_df['passenger_count'] == 9.0 ]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 949956          2  2019-01-05 13:12:29   2019-01-05 13:12:32              9.0
# 1296287         2  2019-01-07 03:19:36   2019-01-07 03:20:01              9.0
# 2012098         2  2019-01-10 00:43:10   2019-01-10 00:43:14              9.0
# 2883995         2  2019-01-13 04:13:24   2019-01-13 04:14:34              9.0
# 4534707         2  2019-01-19 16:45:25   2019-01-19 16:45:27              9.0
# 4852225         2  2019-01-21 03:46:51   2019-01-21 03:46:56              9.0
# 4997790         2  2019-01-21 19:20:28   2019-01-21 19:20:31              9.0
# 7286683         2  2019-01-30 18:34:12   2019-01-30 18:34:16              9.0
# 7373876         2  2019-01-30 22:17:51   2019-01-30 22:44:53              9.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 949956            0.00         5.0                  N            68
# ...

# %%
taxi_df['PULocationID'].value_counts()
# Out:
# PULocationID
# 237    332785
# 236    323295
# 161    312855
# 162    277477
# 230    264134
#         ...
# 204         3
# 176         2
# 199         2
# 84          1
# 104         1
# Name: count, Length: 263, dtype: int64

# %%
taxi_df.isna().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count            28672
# trip_distance                  0
# RatecodeID                 28672
# store_and_fwd_flag         28672
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     4884887
# airport_fee              7696617
# dtype: int64

# %%
taxi_df['RatecodeID'].value_counts()
# Out:
# RatecodeID
# 1.0     7430288
# 2.0      166093
# 5.0       54570
# 3.0       11801
# 4.0        4895
# 99.0        252
# 6.0          46
# Name: count, dtype: int64

# %%
taxi_df[taxi_df['RatecodeID'] == 6.0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 13271           2  2018-11-28 17:04:29   2018-11-28 17:05:00              1.0
# 194468          1  2019-01-02 02:23:48   2019-01-02 02:24:04              1.0
# 195511          1  2019-01-02 04:44:48   2019-01-02 04:49:58              1.0
# 285070          1  2019-01-02 14:55:32   2019-01-02 14:55:37              1.0
# 478818          1  2019-01-03 13:07:49   2019-01-03 13:07:49              1.0
# 478819          1  2019-01-03 13:08:33   2019-01-03 13:08:53              1.0
# 698726          1  2019-01-04 13:38:10   2019-01-04 13:38:15              1.0
# 995379          1  2019-01-05 17:04:34   2019-01-05 17:04:54              1.0
# 1155382         1  2019-01-06 11:56:26   2019-01-06 11:57:47              1.0
# 1212386         1  2019-01-06 16:50:44   2019-01-06 16:50:50              3.0
# 1243588         1  2019-01-06 18:16:47   2019-01-06 18:16:59              1.0
# ...

# %%
better_df = taxi_df[(taxi_df['trip_distance'] > 0.00) & (taxi_df['fare_amount'] < 200.00) & (taxi_df['fare_amount'] > 1.00)]
better_df[better_df['RatecodeID'] == 6.0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 195511          1  2019-01-02 04:44:48   2019-01-02 04:49:58              1.0
# 995379          1  2019-01-05 17:04:34   2019-01-05 17:04:54              1.0
# 1155382         1  2019-01-06 11:56:26   2019-01-06 11:57:47              1.0
# 1243588         1  2019-01-06 18:16:47   2019-01-06 18:16:59              1.0
# 1788364         1  2019-01-09 08:15:57   2019-01-09 08:39:12              1.0
# 2123501         1  2019-01-10 13:17:10   2019-01-10 13:20:58              2.0
# 2189479         1  2019-01-10 17:31:52   2019-01-10 17:32:01              1.0
# 2828669         2  2019-01-12 22:45:00   2019-01-12 22:53:16              1.0
# 2989323         1  2019-01-13 16:39:11   2019-01-13 16:39:17              1.0
# 3466230         1  2019-01-15 16:32:11   2019-01-15 16:33:49              2.0
# 4624249         1  2019-01-19 22:36:10   2019-01-19 22:36:20              1.0
# ...

# %%
better_df['fare_amount'].min()
# Out:
# 1.1

# %%
better_df.reset_index().plot(x = 'index', y= 'total_amount' , kind= 'scatter')
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
taxi_df = better_df[better_df['total_amount'] < 200 ]
taxi_df.shape
# Out:
# (7633604, 19)

# %%
taxi_df.reset_index().plot(x ='index', y= 'total_amount', kind = 'scatter')
plt.show()

# %%
taxi_df[taxi_df['total_amount'] < 3.00].reset_index().plot(x= 'index', y='total_amount' , kind ='scatter')
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
taxi_df[taxi_df['total_amount'] < 3.00].shape
# Out:
# (24, 19)

# %%
taxi_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
taxi_df = taxi_df[['tpep_pickup_datetime', 'tpep_dropoff_datetime',
        'trip_distance', 'PULocationID', 'DOLocationID', 'payment_type', 'total_amount']]

# %%
taxi_df.isna().sum()
# Out:
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# trip_distance            0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# total_amount             0
# dtype: int64

# %%
taxi_data_prepared = taxi_df.copy()

# %%
taxi_data_prepared.dtypes
# Out:
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# trip_distance                   float64
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# total_amount                    float64
# dtype: object

# %%
taxi_data_prepared.loc[:, 'PULocationID'] = taxi_df['PULocationID'].astype(str)
# Out:
# C:\Users\f_bou\AppData\Local\Temp\ipykernel_21320\31283361.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['151' '239' '163' ... '41' '48' '159']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   taxi_data_prepared.loc[:, 'PULocationID'] = taxi_df['PULocationID'].astype(str)

# %%
taxi_data_prepared.loc[:, 'DOLocationID'] = taxi_df['DOLocationID'].astype(str)
taxi_data_prepared.loc[:, 'payment_type'] = taxi_df['payment_type'].astype(str)
# Out:
# C:\Users\f_bou\AppData\Local\Temp\ipykernel_21320\3427182264.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['239' '246' '229' ... '136' '213' '246']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   taxi_data_prepared.loc[:, 'DOLocationID'] = taxi_df['DOLocationID'].astype(str)
# C:\Users\f_bou\AppData\Local\Temp\ipykernel_21320\3427182264.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['1' '1' '1' ... '0' '0' '0']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   taxi_data_prepared.loc[:, 'payment_type'] = taxi_df['payment_type'].astype(str)

# %%
taxi_data_prepared.dtypes
# Out:
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# trip_distance                   float64
# PULocationID                     object
# DOLocationID                     object
# payment_type                     object
# total_amount                    float64
# dtype: object

# %%
taxi_data_prepared['transaction_year'] = taxi_data_prepared['tpep_pickup_datetime'].dt.year
taxi_data_prepared['transaction_date'] = pd.to_datetime(taxi_data_prepared['tpep_pickup_datetime'].dt.date)

# %%
taxi_data_prepared['transaction_month'] = taxi_data_prepared['tpep_pickup_datetime'].dt.month
taxi_data_prepared['transaction_hour'] = taxi_data_prepared['tpep_pickup_datetime'].dt.hour
taxi_data_prepared['transaction_day'] = taxi_data_prepared['tpep_pickup_datetime'].dt.day

# %%
taxi_data_prepared.dtypes
# Out:
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# trip_distance                   float64
# PULocationID                     object
# DOLocationID                     object
# payment_type                     object
# total_amount                    float64
# transaction_year                  int32
# transaction_date         datetime64[ns]
# transaction_month                 int32
# transaction_hour                  int32
# transaction_day                   int32
# dtype: object

# %%
taxi_data_prepared.hist(figsize =(20, 10), bins = 60)
# Out:
# array([[<Axes: title={'center': 'tpep_pickup_datetime'}>,
#         <Axes: title={'center': 'tpep_dropoff_datetime'}>,
#         <Axes: title={'center': 'trip_distance'}>],
#        [<Axes: title={'center': 'total_amount'}>,
#         <Axes: title={'center': 'transaction_year'}>,
#         <Axes: title={'center': 'transaction_date'}>],
#        [<Axes: title={'center': 'transaction_month'}>,
#         <Axes: title={'center': 'transaction_hour'}>,
#         <Axes: title={'center': 'transaction_day'}>]], dtype=object)

# %%
taxi_data_prepared['transaction_year'].value_counts()
# Out:
# transaction_year
# 2019    7633188
# 2018        348
# 2009         44
# 2008         22
# 2088          2
# Name: count, dtype: int64

# %%
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['transaction_year'] == 2019]
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['transaction_month'] == 1]

# %%
taxi_data_prepared['transaction_year'].value_counts()
# Out:
# transaction_year
# 2019    7633096
# Name: count, dtype: int64

# %%
taxi_data_prepared.reset_index().plot(x ='index', y = 'trip_distance', kind= 'scatter')
# Out:
# <Axes: xlabel='index', ylabel='trip_distance'>

# %%
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['trip_distance'] < 400 ]

# %%
taxi_data_prepared['trip_distance'].max()
# Out:
# 211.36

# %%
taxi_data_prepared.reset_index().plot(x ='index', y = 'trip_distance', kind= 'scatter')
# Out:
# <Axes: xlabel='index', ylabel='trip_distance'>

# %%
taxi_data_prepared.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  trip_distance PULocationID  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20            1.5          151
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59            2.6          239
# 7  2019-01-01 00:21:28   2019-01-01 00:28:37            1.3          163
# 8  2019-01-01 00:32:01   2019-01-01 00:45:39            3.7          229
# 9  2019-01-01 00:57:32   2019-01-01 01:09:32            2.1          141
#
#   DOLocationID payment_type  total_amount  transaction_year transaction_date  \
# 0          239            1          9.95              2019       2019-01-01
# 1          246            1         16.30              2019       2019-01-01
# 7          229            1          9.05              2019       2019-01-01
# 8            7            1         18.50              2019       2019-01-01
# 9          234            1         13.00              2019       2019-01-01
#
#    transaction_month  transaction_hour  transaction_day
# ...

# %%
categorical_values = ['PULocationID',  'transaction_date', 'transaction_day', 'transaction_hour']
numerical_values = ['trip_distance' , 'total_amount']
all_need = categorical_values + numerical_values

# %%
taxi_data_prepared[all_need].head()
# Out:
#   PULocationID transaction_date  transaction_day  transaction_hour  \
# 0          151       2019-01-01                1                 0
# 1          239       2019-01-01                1                 0
# 7          163       2019-01-01                1                 0
# 8          229       2019-01-01                1                 0
# 9          141       2019-01-01                1                 0
#
#    trip_distance  total_amount
# 0            1.5          9.95
# 1            2.6         16.30
# 7            1.3          9.05
# 8            3.7         18.50
# 9            2.1         13.00

# %%
main_df = taxi_data_prepared[all_need].copy()

# %%
main_df.dtypes
# Out:
# PULocationID                object
# transaction_date    datetime64[ns]
# transaction_day              int32
# transaction_hour             int32
# trip_distance              float64
# total_amount               float64
# dtype: object

# %%
groupby_region_data = main_df.groupby(categorical_values).mean().reset_index()

# %%
groupby_region_data.head()
# Out:
#   PULocationID transaction_date  transaction_day  transaction_hour  \
# 0            1       2019-01-01                1                10
# 1            1       2019-01-01                1                12
# 2            1       2019-01-01                1                15
# 3            1       2019-01-01                1                19
# 4            1       2019-01-02                2                 2
#
#    trip_distance  total_amount
# 0          16.90         69.93
# 1          19.30        198.35
# 2          41.28        118.32
# 3           0.11        142.36
# 4           1.27         30.30

# %%
main_df.dtypes
# Out:
# PULocationID                object
# transaction_date    datetime64[ns]
# transaction_day              int32
# transaction_hour             int32
# trip_distance              float64
# total_amount               float64
# dtype: object

# %%
groupby_region_data[(groupby_region_data['transaction_date'] == '2019-01-01') & (groupby_region_data['transaction_hour'] == 0 )]
# Out:
#        PULocationID transaction_date  transaction_day  transaction_hour  \
# 108              10       2019-01-01                1                 0
# 744             100       2019-01-01                1                 0
# 1771            106       2019-01-01                1                 0
# 2219            107       2019-01-01                1                 0
# 3098             11       2019-01-01                1                 0
# ...             ...              ...              ...               ...
# 97624            90       2019-01-01                1                 0
# 98753            92       2019-01-01                1                 0
# 99059            93       2019-01-01                1                 0
# 99568            94       2019-01-01                1                 0
# 100271           97       2019-01-01                1                 0
#
#         trip_distance  total_amount
# 108          3.020000     14.300000
# ...

# %%
groupby_region_data['transaction_count'] = main_df.groupby(categorical_values).count().reset_index()['total_amount']

# %%
groupby_region_data.head()
# Out:
#   PULocationID transaction_date  transaction_day  transaction_hour  \
# 0            1       2019-01-01                1                10
# 1            1       2019-01-01                1                12
# 2            1       2019-01-01                1                15
# 3            1       2019-01-01                1                19
# 4            1       2019-01-02                2                 2
#
#    trip_distance  total_amount  transaction_count
# 0          16.90         69.93                  2
# 1          19.30        198.35                  1
# 2          41.28        118.32                  1
# 3           0.11        142.36                  1
# 4           1.27         30.30                  1

# %%
groupby_region_data[(groupby_region_data['transaction_day'] == 1) & (groupby_region_data['PULocationID'] == '1')]
# Out:
#   PULocationID transaction_date  transaction_day  transaction_hour  \
# 0            1       2019-01-01                1                10
# 1            1       2019-01-01                1                12
# 2            1       2019-01-01                1                15
# 3            1       2019-01-01                1                19
#
#    trip_distance  total_amount  transaction_count
# 0          16.90         69.93                  2
# 1          19.30        198.35                  1
# 2          41.28        118.32                  1
# 3           0.11        142.36                  1

# %% [markdown]
# ## Benchmark model

# %%
data_for_benchmark_model = groupby_region_data.copy()

# %%
categorical_features = ['PULocationID', 'transaction_day', 'transaction_hour']
input_features = categorical_features 
target_feature = 'total_amount'

# %%
from sklearn.model_selection import train_test_split

X = data_for_benchmark_model[input_features]
Y = data_for_benchmark_model[target_feature]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state= 42)

# %%
from sklearn.tree import DecisionTreeRegressor

tree = DecisionTreeRegressor(max_depth = 10)
tree.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
model_at_hand = tree

Y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

print('mean absolute error : ', mean_absolute_error(Y_test, Y_pred))
print('mean squared error : ', mean_squared_error(Y_test, Y_pred)) 
print('root mean squared error : ', sqrt(mean_squared_error(Y_test, Y_pred)))
print('score : ', r2_score(Y_test, Y_pred))
# Out:
# mean absolute error :  8.838000042548195
# mean squared error :  203.3580551538697
# root mean squared error :  14.260366585535932
# score :  0.2786128973801446

# %%
data = {"test" :Y_test, 'pred': Y_pred }

results = pd.DataFrame(data)

results.reset_index().plot( y = 'test', x= 'pred', kind= 'scatter', figsize=(15, 10))
# Out:
# <Axes: xlabel='pred', ylabel='test'>
